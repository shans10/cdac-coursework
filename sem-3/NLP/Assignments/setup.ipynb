# %%
import gensim.downloader as api

print("⬇ Downloading pre-trained GloVe (50D)...")
api.load("glove-wiki-gigaword-50")

print("✅ GloVe Embeddings Ready for Use")
# Out:
# ⬇ Downloading pre-trained GloVe (50D)...
# ✅ GloVe Embeddings Ready for Use

# %%
import nltk, spacy, gensim, sklearn, transformers, speech_recognition
print("✅ All libraries loaded successfully. Setup Verified.")
# Out:
# ✅ All libraries loaded successfully. Setup Verified.
